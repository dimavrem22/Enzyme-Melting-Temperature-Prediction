# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt

# %%
columns = ['Model Type', 'MSE', 'RMSE', 'MAE', 'R2']

models = ['Multiple Linear Regression', 'Ridge Regression', 'Lasso Regression', 
          'Decision Tree', 'Random Forest', 'Support Vector Regression', 'Multiple Layer Perceptron']

mse = [80.67549395542376, 80.58399059845095, 105.95283093537297, 
       137.44547176904572, 65.79677683055772, 84.24235523562217,63.538639858225324]

rmse = [8.981953793881583, 8.976858615264637, 10.293339153810729, 
        11.723714077417862, 8.11152124022108, 9.178363429044536, 7.971112836877002]

mae = [6.861408268545967, 6.85866156107049, 7.6454211479814, 
       8.304966189339698, 5.9213124792646195, 6.504254758772979, 6.025044014744679]

r2 = [0.5241836697577554, 0.5247233477861751, 0.375100359195795, 
      0.18935978226923966, 0.6119369171686472, 0.5031466638267486, 0.6252551925789374]

# %%
result_table = pd.DataFrame([models, mse, rmse, mae, r2
result_table = result_table.transpose()
result_table.columns = columns
result_table
# Out:
#                    Model Type         MSE       RMSE       MAE        R2
# 0  Multiple Linear Regression   80.675494   8.981954  6.861408  0.524184
# 1            Ridge Regression   80.583991   8.976859  6.858662  0.524723
# 2            Lasso Regression  105.952831  10.293339  7.645421    0.3751
# 3               Decision Tree  137.445472  11.723714  8.304966   0.18936
# 4               Random Forest   65.796777   8.111521  5.921312  0.611937
# 5   Support Vector Regression   84.242355   9.178363  6.504255  0.503147
# 6   Multiple Layer Perceptron    63.53864   7.971113  6.025044  0.625255
